# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import itertools
import warnings
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
from pylab import rcParams

# %%
data = pd.read_csv('Final.csv')
print(data.dtypes)
data
# Out:
# UserName            object
# ProductName         object
# ProductType         object
# TransactionType     object
# Amount             float64
# CashBacks          float64
# TransactionDate     object
# TransactionTime     object
# dtype: object
#               UserName          ProductName ProductType TransactionType  \
# 0        Nicholas Rose  CrazyLivelyHood.com     Paysite           Sales
# 1                  NaN  CrazyLivelyHood.com     Paysite           Sales
# 2        Nicholas Rose  CrazyLivelyHood.com     Paysite           Sales
# 3         Dustin Dixon  CrazyLivelyHood.com     Paysite           Sales
# 4                  NaN  CrazyLivelyHood.com     Paysite           Sales
# ..                 ...                  ...         ...             ...
# 198  Francisco Sanchez    CthuluhsSpawn.com    Freemium           Sales
# 199  Francisco Sanchez    CthuluhsSpawn.com    Freemium           Sales
# 200  Francisco Sanchez    CthuluhsSpawn.com    Freemium           Sales
# 201  Francisco Sanchez    CthuluhsSpawn.com    Freemium           Sales
# 202  Francisco Sanchez    CthuluhsSpawn.com    Freemium           Sales
#
#      Amount  CashBacks TransactionDate TransactionTime
# 0     97.56        NaN      2020-01-30            0:00
# 1    120.15        NaN      2020-01-30            1:00
# 2      4.46        NaN      2020-01-31            2:00
# 3      6.22        NaN      2020-01-31            3:00
# 4     57.30        NaN      2020-01-31            4:00
# ..      ...        ...             ...             ...
# 198   20.00        NaN      2020-01-31            6:00
# 199   20.00        NaN      2020-02-07            7:00
# 200   20.00        NaN      2020-02-14            8:00
# 201   20.00        NaN      2020-02-21            9:00
# 202   20.00        NaN      2020-02-28           10:00
#
# [203 rows x 8 columns]

# %%
data = pd.read_csv('Final.csv', parse_dates=[['TransactionDate','TransactionTime']], index_col='TransactionDate_TransactionTime')
print(data.dtypes)
data['Amount'] = data['Amount'].fillna(0)
data
# Out:
# UserName            object
# ProductName         object
# ProductType         object
# TransactionType     object
# Amount             float64
# CashBacks          float64
# dtype: object
#                                           UserName          ProductName  \
# TransactionDate_TransactionTime
# 2020-01-30 00:00:00                  Nicholas Rose  CrazyLivelyHood.com
# 2020-01-30 01:00:00                            NaN  CrazyLivelyHood.com
# 2020-01-31 02:00:00                  Nicholas Rose  CrazyLivelyHood.com
# 2020-01-31 03:00:00                   Dustin Dixon  CrazyLivelyHood.com
# 2020-01-31 04:00:00                            NaN  CrazyLivelyHood.com
# ...                                            ...                  ...
# 2020-01-31 06:00:00              Francisco Sanchez    CthuluhsSpawn.com
# 2020-02-07 07:00:00              Francisco Sanchez    CthuluhsSpawn.com
# 2020-02-14 08:00:00              Francisco Sanchez    CthuluhsSpawn.com
# 2020-02-21 09:00:00              Francisco Sanchez    CthuluhsSpawn.com
# 2020-02-28 10:00:00              Francisco Sanchez    CthuluhsSpawn.com
#
#                                 ProductType TransactionType  Amount  CashBacks
# TransactionDate_TransactionTime
# 2020-01-30 00:00:00                 Paysite           Sales   97.56        NaN
# 2020-01-30 01:00:00                 Paysite           Sales  120.15        NaN
# 2020-01-31 02:00:00                 Paysite           Sales    4.46        NaN
# 2020-01-31 03:00:00                 Paysite           Sales    6.22        NaN
# 2020-01-31 04:00:00                 Paysite           Sales   57.30        NaN
# ...                                     ...             ...     ...        ...
# 2020-01-31 06:00:00                Freemium           Sales   20.00        NaN
# 2020-02-07 07:00:00                Freemium           Sales   20.00        NaN
# 2020-02-14 08:00:00                Freemium           Sales   20.00        NaN
# 2020-02-21 09:00:00                Freemium           Sales   20.00        NaN
# 2020-02-28 10:00:00                Freemium           Sales   20.00        NaN
#
# [203 rows x 6 columns]

# %%
data.index
# Out:
# DatetimeIndex(['2020-01-30 00:00:00', '2020-01-30 01:00:00',
#                '2020-01-31 02:00:00', '2020-01-31 03:00:00',
#                '2020-01-31 04:00:00', '2020-02-01 05:00:00',
#                '2020-02-01 06:00:00', '2020-02-01 07:00:00',
#                '2020-02-02 08:00:00', '2020-02-02 09:00:00',
#                ...
#                '2020-03-01 01:00:00', '2020-02-15 02:00:00',
#                '2020-02-17 03:00:00', '2020-02-23 04:00:00',
#                '2020-02-26 05:00:00', '2020-01-31 06:00:00',
#                '2020-02-07 07:00:00', '2020-02-14 08:00:00',
#                '2020-02-21 09:00:00', '2020-02-28 10:00:00'],
#               dtype='datetime64[ns]', name='TransactionDate_TransactionTime', length=203, freq=None)

# %%
data.drop(data[data['ProductName'] != 'CrazyLivelyHood.com'].index, inplace = True) 
data
# Out:
#                                       UserName          ProductName  \
# TransactionDate_TransactionTime
# 2020-01-30 00:00:00              Nicholas Rose  CrazyLivelyHood.com
# 2020-01-30 01:00:00                        NaN  CrazyLivelyHood.com
# 2020-01-31 02:00:00              Nicholas Rose  CrazyLivelyHood.com
# 2020-01-31 03:00:00               Dustin Dixon  CrazyLivelyHood.com
# 2020-01-31 04:00:00                        NaN  CrazyLivelyHood.com
# ...                                        ...                  ...
# 2020-02-14 23:00:00                        NaN  CrazyLivelyHood.com
# 2020-02-17 00:00:00               Lisa Johnson  CrazyLivelyHood.com
# 2020-02-17 01:00:00                        NaN  CrazyLivelyHood.com
# 2020-02-29 04:00:00                        NaN  CrazyLivelyHood.com
# 2020-03-01 05:00:00                        NaN  CrazyLivelyHood.com
#
#                                 ProductType TransactionType  Amount  CashBacks
# TransactionDate_TransactionTime
# 2020-01-30 00:00:00                 Paysite           Sales   97.56        NaN
# 2020-01-30 01:00:00                 Paysite           Sales  120.15        NaN
# 2020-01-31 02:00:00                 Paysite           Sales    4.46        NaN
# 2020-01-31 03:00:00                 Paysite           Sales    6.22        NaN
# 2020-01-31 04:00:00                 Paysite           Sales   57.30        NaN
# ...                                     ...             ...     ...        ...
# 2020-02-14 23:00:00                 Paysite        Cashback    0.00     -53.25
# 2020-02-17 00:00:00                 Paysite        Cashback    0.00    -791.09
# 2020-02-17 01:00:00                 Paysite        Cashback    0.00     -90.55
# 2020-02-29 04:00:00                 Paysite        Cashback    0.00     -55.74
# 2020-03-01 05:00:00                 Paysite        Cashback    0.00     -61.29
#
# [113 rows x 6 columns]

# %%
ts = data['Amount']
ts.head(113)
# Out:
# TransactionDate_TransactionTime
# 2020-01-30 00:00:00     97.56
# 2020-01-30 01:00:00    120.15
# 2020-01-31 02:00:00      4.46
# 2020-01-31 03:00:00      6.22
# 2020-01-31 04:00:00     57.30
#                         ...
# 2020-02-14 23:00:00      0.00
# 2020-02-17 00:00:00      0.00
# 2020-02-17 01:00:00      0.00
# 2020-02-29 04:00:00      0.00
# 2020-03-01 05:00:00      0.00
# Name: Amount, Length: 113, dtype: float64

# %%
plt.plot(ts)
plt.show()

# %%
ts.rolling(window=1).mean().plot(figsize=(15, 6))
# Out:
# <AxesSubplot:xlabel='TransactionDate_TransactionTime'>

# %%
ts.sort_index(inplace=True)
ts['2020':]
print(ts)


# Resampled to everyday frequency as it reqires minimum 24 entries
y = ts.resample('D').mean()
#To obtain sales in year 2020
y['2020':]


# For trend,seasonality, and noise

rcParams['figure.figsize'] = 25, 18
decomposition = sm.tsa.seasonal_decompose(y, model='additive')
fig = decomposition.plot()
plt.show()
# Out:
# TransactionDate_TransactionTime
# 2020-01-30 00:00:00     97.56
# 2020-01-30 01:00:00    120.15
# 2020-01-30 13:00:00      2.05
# 2020-01-30 16:00:00      0.00
# 2020-01-31 02:00:00      4.46
#                         ...
# 2020-03-01 05:00:00      0.00
# 2020-03-01 09:00:00     96.13
# 2020-03-01 10:00:00      3.01
# 2020-03-01 11:00:00     30.98
# 2020-03-01 12:00:00     57.19
# Name: Amount, Length: 113, dtype: float64

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:391.8889970890196
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:248.30122891395672
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:242.56485721875276
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:93.53369178162703
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:255.77911197554891
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:245.03162056782512
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:105.56469599704212
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:95.05594857532981
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:368.668773327135
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:228.13233900802317
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:232.13980545845763
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:83.24171186830311
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:251.01026326229047
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:230.12321955246315
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:104.39888452000261
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:82.47178127826137
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:373.40703301811584
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:231.24884848966303
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:241.8777024917255
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:84.89755292872827
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:242.80347864638787
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:232.6685632955735
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:88.30428266394628
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:78.7322565121004
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:348.22424422836565
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:212.65898789058085
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:221.0419573695402
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:69.95862533226835
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:236.32408954058653
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:214.5049611087532
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:90.23625695213126
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:63.16680434271897
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:379.94764237203714
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:242.0258208253911
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:244.50751943359109
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:95.42057542296904
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:242.40804783934618
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:243.961014582209
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:89.79726454501973
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:91.69692587945937
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:360.2467998586482
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:226.3606402189694
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:232.80492666148962
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:84.87942062152254
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:237.29075890505342
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:227.81546021873797
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:91.56293498507345
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:82.07371364220413
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:372.77170000711794
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:232.71478539878785
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:242.26628412080706
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:86.00938562476142
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:232.132900067866
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:233.99224023455645
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:78.73024140979304
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:80.73341503234401
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:350.18336447146737
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:214.65785537330365
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:222.93000769903165
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:71.89054835294804
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:226.65018496635773
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:216.48245354088897
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:79.57315714996481
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:65.15809145286772
# /Users/monalgosai/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 0, 12),
                                enforce_stationarity=True,
                                enforce_invertibility=False, error='ignore')

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0694      0.261     -0.265      0.791      -0.582       0.443
# ma.L1         -1.0000      1.363     -0.734      0.463      -3.671       1.671
# ar.S.L12      -0.6629      0.671     -0.989      0.323      -1.977       0.651
# sigma2      9245.9951      0.000   6.27e+07      0.000    9245.995    9245.995
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(20, 20))
plt.show()

# %%
#Forcasting sales on CrazyLivelyHood.com foe next two months

pred_uc = results.get_forecast(steps=90)
pred_ci = pred_uc.conf_int()

ax = y.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
pred_ci.iloc[:, 0],
pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Revenue')
plt.legend()
plt.show()
